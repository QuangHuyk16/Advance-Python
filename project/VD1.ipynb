# %%
import requests 
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

reponse  = requests.get('https://www.nchmf.gov.vn/kttv/')
soup = BeautifulSoup(reponse.content,'html.parser')

data = soup.find_all('div',class_='wt-city uk-position-relative uk-box-shadow-small')
link=[]
province_name =[]
temp=[]
for item in data:
    title = item.find('h2').text
    data1 = item.find_all('li')
    for j in data1:
        link.append(j.a.get('href'))
        province_name.append(j.find('a',class_='name-wt-city').text.strip())
    for item2 in data1:
        temp.append(item2.find('div',class_='temp-wt-city').text)
print(title)
print(temp)
print(link)
df = pd.DataFrame({'province_name':province_name,
                   'temp':temp,
                   'link':link})
df.to_csv(r'D:\Advance Python\data\nhiet_do_ca_nuoc.csv')
# Out:
# THỜI TIẾT CÁC TỈNH / THÀNH - CẬP NHẬT LÚC 10h - 25/03/2024
# ['25°C', '22°C', '25°C', '30°C', '29°C', '26°C', '28°C', '28°C', '29°C', '26°C', '24°C', '27°C', '28°C', '26°C', '25°C', '27°C', '27°C', '26°C', '27°C', '26°C', '25°C', '25°C', '25°C', '25°C', '24°C', '26°C', '25°C', '25°C', '25°C', '24°C', '30°C', '30°C', '26°C', '31°C', '29°C', '30°C', '30°C', '31°C', '30°C', '24°C', '26°C', '29°C', '29°C', '23°C', '25°C', '26°C', '27°C', '28°C', '31°C', '30°C', '25°C', '27°C', '26°C', '28°C', '25°C', '25°C', '25°C', '31°C', '26°C', '26°C', '31°C', '27°C', '31°C']
# ['https://nchmf.gov.vn/Kttv/vi-VN/1/lai-chau-w64.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/dien-bien-w38.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/son-la-w45.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/hoa-binh-w2.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/lao-cai-w37.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/yen-bai-w53.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ha-giang-w36.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/tuyen-quang-w50.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/bac-can-w52.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/thai-nguyen-w51.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/phu-tho-w43.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/vinh-phuc-w44.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/cao-bang-w49.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/lang-son-w48.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/quang-ninh-w63.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/bac-giang-w46.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/bac-ninh-w47.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/hai-phong-w54.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ha-noi-w28.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/hai-duong-w19.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/hung-yen-w33.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/nam-dinh-w34.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ha-nam-w20.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ninh-binh-w17.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/thai-binh-w18.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/thanh-hoa-w61.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/nghe-an-w3.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ha-tinh-w4.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/quang-binh-w5.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/quang-tri-w6.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/hue-w7.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/da-nang-w55.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/quang-nam-w62.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/quang-ngai-w8.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/binh-dinh-w56.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/phu-yen-w59.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/khanh-hoa-w9.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ninh-thuan-w60.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/binh-thuan-w10.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/kon-tum-w11.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/gia-lai-w12.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/dac-lak-w13.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/dac-nong-w39.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/lam-dong-w14.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/binh-phuoc-w30.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/tay-ninh-w35.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/dong-nai-w32.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/binh-duong-w16.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ho-chi-minh-w15.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/br-vung-tau-w31.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/long-an-w21.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/tien-giang-w23.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/vinh-long-w57.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ben-tre-w24.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/dong-thap-w22.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/tra-vinh-w25.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/an-giang-w58.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/can-tho-w26.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/hau-giang-w40.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/soc-trang-w27.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/kien-giang-w41.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/bac-lieu-w29.html', 'https://nchmf.gov.vn/Kttv/vi-VN/1/ca-mau-w42.html']

# %%
data = pd.read_csv(r'D:\Advance Python\data\nhiet_do_ca_nuoc.csv')
data
# Out:
#     Unnamed: 0 province_name  temp  \
# 0            0      Lai Châu  25°C
# 1            1     Điện Biên  22°C
# 2            2        Sơn La  25°C
# 3            3      Hòa Bình  30°C
# 4            4       Lào Cai  29°C
# ..         ...           ...   ...
# 58          58     Hậu Giang  26°C
# 59          59     Sóc Trăng  26°C
# 60          60    Kiên Giang  31°C
# 61          61      Bạc Liêu  27°C
# 62          62        Cà Mau  31°C
#
#                                                  link
# 0   https://nchmf.gov.vn/Kttv/vi-VN/1/lai-chau-w64...
# 1   https://nchmf.gov.vn/Kttv/vi-VN/1/dien-bien-w3...
# 2   https://nchmf.gov.vn/Kttv/vi-VN/1/son-la-w45.html
# 3   https://nchmf.gov.vn/Kttv/vi-VN/1/hoa-binh-w2....
# 4   https://nchmf.gov.vn/Kttv/vi-VN/1/lao-cai-w37....
# ..                                                ...
# 58  https://nchmf.gov.vn/Kttv/vi-VN/1/hau-giang-w4...
# 59  https://nchmf.gov.vn/Kttv/vi-VN/1/soc-trang-w2...
# 60  https://nchmf.gov.vn/Kttv/vi-VN/1/kien-giang-w...
# 61  https://nchmf.gov.vn/Kttv/vi-VN/1/bac-lieu-w29...
# 62  https://nchmf.gov.vn/Kttv/vi-VN/1/ca-mau-w42.html
#
# [63 rows x 4 columns]

# %%
print('province have temp highest :')
data[data['temp'] == max(data['temp'])]['province_name']
# Out:
# province have temp highest :
# 33     Quảng Ngãi
# 37     Ninh Thuận
# 48    Hồ Chí Minh
# 57        Cần Thơ
# 60     Kiên Giang
# 62         Cà Mau
# Name: province_name, dtype: object

# %%
data.head()
# Out:
#    Unnamed: 0 province_name  temp  \
# 0           0      Lai Châu  25°C
# 1           1     Điện Biên  22°C
# 2           2        Sơn La  25°C
# 3           3      Hòa Bình  30°C
# 4           4       Lào Cai  29°C
#
#                                                 link
# 0  https://nchmf.gov.vn/Kttv/vi-VN/1/lai-chau-w64...
# 1  https://nchmf.gov.vn/Kttv/vi-VN/1/dien-bien-w3...
# 2  https://nchmf.gov.vn/Kttv/vi-VN/1/son-la-w45.html
# 3  https://nchmf.gov.vn/Kttv/vi-VN/1/hoa-binh-w2....
# 4  https://nchmf.gov.vn/Kttv/vi-VN/1/lao-cai-w37....

# %%
temp_number=[]
for i in data['temp']:
    temp_number.append(int(str(i).replace("°C",'')))
data['temp'] = temp_number
data
# Out:
#     Unnamed: 0 province_name  temp  \
# 0            0      Lai Châu    25
# 1            1     Điện Biên    22
# 2            2        Sơn La    25
# 3            3      Hòa Bình    30
# 4            4       Lào Cai    29
# ..         ...           ...   ...
# 58          58     Hậu Giang    26
# 59          59     Sóc Trăng    26
# 60          60    Kiên Giang    31
# 61          61      Bạc Liêu    27
# 62          62        Cà Mau    31
#
#                                                  link
# 0   https://nchmf.gov.vn/Kttv/vi-VN/1/lai-chau-w64...
# 1   https://nchmf.gov.vn/Kttv/vi-VN/1/dien-bien-w3...
# 2   https://nchmf.gov.vn/Kttv/vi-VN/1/son-la-w45.html
# 3   https://nchmf.gov.vn/Kttv/vi-VN/1/hoa-binh-w2....
# 4   https://nchmf.gov.vn/Kttv/vi-VN/1/lao-cai-w37....
# ..                                                ...
# 58  https://nchmf.gov.vn/Kttv/vi-VN/1/hau-giang-w4...
# 59  https://nchmf.gov.vn/Kttv/vi-VN/1/soc-trang-w2...
# 60  https://nchmf.gov.vn/Kttv/vi-VN/1/kien-giang-w...
# 61  https://nchmf.gov.vn/Kttv/vi-VN/1/bac-lieu-w29...
# 62  https://nchmf.gov.vn/Kttv/vi-VN/1/ca-mau-w42.html
#
# [63 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     63 non-null     int64
#  1   province_name  63 non-null     object
#  2   temp           63 non-null     int64
#  3   link           63 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 2.1+ KB

# %%
print('nhiet do trung binh:')
data['temp'].mean()
# Out:
# nhiet do trung binh:
# 26.952380952380953

# %%
print('do lech chuan:')
data['temp'].std()
# Out:
# do lech chuan:
# 2.317037676532267

# %%
data
# Out:
#     Unnamed: 0 province_name  temp  \
# 0            0      Lai Châu    25
# 1            1     Điện Biên    22
# 2            2        Sơn La    25
# 3            3      Hòa Bình    30
# 4            4       Lào Cai    29
# ..         ...           ...   ...
# 58          58     Hậu Giang    26
# 59          59     Sóc Trăng    26
# 60          60    Kiên Giang    31
# 61          61      Bạc Liêu    27
# 62          62        Cà Mau    31
#
#                                                  link
# 0   https://nchmf.gov.vn/Kttv/vi-VN/1/lai-chau-w64...
# 1   https://nchmf.gov.vn/Kttv/vi-VN/1/dien-bien-w3...
# 2   https://nchmf.gov.vn/Kttv/vi-VN/1/son-la-w45.html
# 3   https://nchmf.gov.vn/Kttv/vi-VN/1/hoa-binh-w2....
# 4   https://nchmf.gov.vn/Kttv/vi-VN/1/lao-cai-w37....
# ..                                                ...
# 58  https://nchmf.gov.vn/Kttv/vi-VN/1/hau-giang-w4...
# 59  https://nchmf.gov.vn/Kttv/vi-VN/1/soc-trang-w2...
# 60  https://nchmf.gov.vn/Kttv/vi-VN/1/kien-giang-w...
# 61  https://nchmf.gov.vn/Kttv/vi-VN/1/bac-lieu-w29...
# 62  https://nchmf.gov.vn/Kttv/vi-VN/1/ca-mau-w42.html
#
# [63 rows x 4 columns]
